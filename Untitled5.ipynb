# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data_science.csv')

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %%
df.drop(df[['Unnamed: 0','salary']],axis = 1,inplace = True)

# %%
df1 = df.groupby('work_year')['salary_in_usd'].mean().round(2)

# %%
df1
# Out:
# work_year
# 2020     95813.00
# 2021     99853.79
# 2022    124522.01
# Name: salary_in_usd, dtype: float64

# %%
data = {
    'work_year':df1.index,
    'avrage_salary':df1.values
}

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#    work_year  avrage_salary
# 0       2020       95813.00
# 1       2021       99853.79
# 2       2022      124522.01

# %%
data_frame['avrage_salary'] = (data_frame['avrage_salary']/1000).round(2)

# %%
data_frame
# Out:
#    work_year  avrage_salary
# 0       2020          95.81
# 1       2021          99.85
# 2       2022         124.52

# %%
data_frame.plot(kind = 'bar',x = 'work_year',y = 'avrage_salary',legend = True)
# Out:
# <Axes: xlabel='work_year'>

# %%
ax = data_frame.plot(kind = 'bar',x = 'work_year',y = 'avrage_salary',legend = True)
ax.bar_label(ax.containers[0],labels = data_frame['avrage_salary'].map('{:.2f}k'.format))
plt.show()

# %%
dff = df.remote_ratio.value_counts()

# %%
value = dff.to_list()

# %%
value
# Out:
# [381, 127, 99]

# %%
labels = ['Fully remote', 'No remote', 'Partially remote']

# %%
z = plt.bar(labels,value,width = 0.5,color = 'orange')
plt.bar_label(z,labels = value)
# Out:
# [Text(0, 0, '381'), Text(0, 0, '127'), Text(0, 0, '99')]

# %%
df3 = df.company_size.value_counts()
df3
# Out:
# company_size
# M    326
# L    198
# S     83
# Name: count, dtype: int64

# %%
values2 = df3.to_list()
values2
# Out:
# [326, 198, 83]

# %%
labels_of_company = ["Medium", "Large", "Small"]
labels_of_company
# Out:
# ['Medium', 'Large', 'Small']

# %%
plt.pie(x = values2, labels = None, autopct = '%1.1f%%')
plt.legend(labels = labels_of_company, loc = 'upper right')
plt.axis('equal')
plt.title("Company_size")
plt.show()

# %%
df4 = df.job_title.value_counts().head()
df4
# Out:
# job_title
# Data Scientist               143
# Data Engineer                132
# Data Analyst                  97
# Machine Learning Engineer     41
# Research Scientist            16
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = df4.index,y = df4.values,palette= "viridis")
plt.xticks(rotation = -15)
plt.ylabel('counts')
plt.xlabel('Job Title')
plt.show()

# %%
df5 = df[["salary_in_usd", "company_size"]]
df5
# Out:
#      salary_in_usd company_size
# 0            79833            L
# 1           260000            S
# 2           109024            M
# 3            20000            S
# 4           150000            L
# ..             ...          ...
# 602         154000            M
# 603         126000            M
# 604         129000            M
# 605         150000            M
# 606         200000            L
#
# [607 rows x 2 columns]

# %%
S = df5[df5['company_size'] == 'S']
M = df5[df5['company_size'] == 'M']
L = df5[df5['company_size'] == "L"]

labels = ['Small','Medium', 'Large']
sal_mean = [S['salary_in_usd'].mean(), M["salary_in_usd"].mean(), L["salary_in_usd"].mean()]
sal_mean
# Out:
# [77632.67469879518, 116905.46625766871, 119242.99494949495]

# %%
label_change = np.round([x/1000 for x in sal_mean], 2)
label_change = list(map(str, label_change))
label_change = [x + ' K' for x in label_change]
label_change
# Out:
# ['77.63 K', '116.91 K', '119.24 K']

# %%
z = plt.bar(labels, sal_mean)
plt.bar_label(z,label_change, alpha = 0.8)
plt.title('Distribution of salary by comapny size')
plt.xlabel('Size of company')
plt.ylabel('Salary in usd')
plt.show()

# %%
sns.histplot(S['salary_in_usd'],label = 'Small',kde = True)
sns.histplot(M['salary_in_usd'],label = 'Small',kde = True)
sns.histplot(L['salary_in_usd'],label = 'Small',kde = True)
plt.title('Distribution of salary by comapny size')
plt.xlabel('Size of company')
plt.ylabel('Salary in usd')
plt.show()
# Out:
# C:\Users\AYAAN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AYAAN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AYAAN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
