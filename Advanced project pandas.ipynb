# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
f500 = pd.read_csv("f500.csv")

# %%
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
500*17
# Out:
# 8500

# %%
f500.shape
# Out:
# (500, 17)

# %%
f500.shape[0]
# Out:
# 500

# %%
f500.shape[1]
# Out:
# 17

# %%
f500.dtypes
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.head(10)
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
# 6         Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7        Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                     Apple     9    215639            -7.7  45687.0  321686
# 9               Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 1           -6.2              Kou Wei
# ...

# %%
f500.tail()
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
#      assets  profit_change                 ceo  \
# 495   92890          -79.3   Yitzhak Peterburg
# 496  100609          -45.6            Wan Feng
# 497   11630           20.4      David T. Potts
# 498   16247          195.5   Friedrich Joussen
# 499   10060           -2.7  Michael J. Jackson
#
#                             industry              sector  previous_rank  \
# 495                  Pharmaceuticals         Health Care              0
# ...

# %%
f500.tail(2)
# Out:
#         company  rank  revenues  revenue_change  profits  assets  \
# 498         TUI   499     21655            -5.5   1151.7   16247
# 499  AutoNation   500     21609             3.6    430.5   10060
#
#      profit_change                 ceo             industry  \
# 498          195.5   Friedrich Joussen      Travel Services
# 499           -2.7  Michael J. Jackson  Specialty Retailers
#
#                 sector  previous_rank  country          hq_location  \
# 498  Business Services            467  Germany     Hanover, Germany
# 499          Retailing              0      USA  Fort Lauderdale, FL
#
#                        website  years_on_global_500_list  employees  \
# 498    http://www.tuigroup.com                        23      66779
# 499  http://www.autonation.com                        12      26000
#
#      total_stockholder_equity
# 498                      3006
# 499                      2310

# %%
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
f500['company']
# Out:
# 0                             Walmart
# 1                          State Grid
# 2                       Sinopec Group
# 3            China National Petroleum
# 4                        Toyota Motor
#                     ...
# 495    Teva Pharmaceutical Industries
# 496          New China Life Insurance
# 497         Wm. Morrison Supermarkets
# 498                               TUI
# 499                        AutoNation
# Name: company, Length: 500, dtype: object

# %%
for i in f500['company']:
    print(i)
# Out:
# Walmart
# State Grid
# Sinopec Group
# China National Petroleum
# Toyota Motor
# Volkswagen
# Royal Dutch Shell
# Berkshire Hathaway
# Apple
# Exxon Mobil
# McKesson
# BP
# UnitedHealth Group
# CVS Health
# Samsung Electronics
# Glencore
# Daimler
# General Motors
# AT&T
# EXOR Group
# Ford Motor
# Industrial & Commercial Bank of China
# AmerisourceBergen
# China State Construction Engineering
# AXA
# Amazon.com
# Hon Hai Precision Industry
# China Construction Bank
# Honda Motor
# Total
# General Electric
# Verizon
# Japan Post Holdings
# Allianz
# Cardinal Health
# Costco
# Walgreens Boots Alliance
# Agricultural Bank of China
# Ping An Insurance
# Kroger
# SAIC Motor
# Bank of China
# BNP Paribas
# Nissan Motor
# Chevron
# Fannie Mae
# China Mobile Communications
# J.P. Morgan Chase
# Legal & General Group
# Nippon Telegraph & Telephone
# China Life Insurance
# BMW Group
# Express Scripts Holding
# Trafigura Group
# China Railway Engineering
# Prudential
# Assicurazioni Generali
# ...

# %%
f500['company'].head()
# Out:
# 0                     Walmart
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# Name: company, dtype: object

# %%
f500.head(2)
# Out:
#       company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0     Walmart     1    485873             0.8  13643.0  198825           -7.2
# 1  State Grid     2    315199            -4.4   9571.3  489838           -6.2
#
#                    ceo               industry     sector  previous_rank  \
# 0  C. Douglas McMillon  General Merchandisers  Retailing              1
# 1              Kou Wei              Utilities     Energy              2
#
#   country      hq_location                 website  years_on_global_500_list  \
# 0     USA  Bentonville, AR  http://www.walmart.com                        23
# 1   China   Beijing, China  http://www.sgcc.com.cn                        17
#
#    employees  total_stockholder_equity
# 0    2300000                     77798
# 1     926067                    209456

# %%
f500[["company","ceo","industry","rank"]]
# Out:
#                             company                  ceo  \
# 0                           Walmart  C. Douglas McMillon
# 1                        State Grid              Kou Wei
# 2                     Sinopec Group            Wang Yupu
# 3          China National Petroleum        Zhang Jianhua
# 4                      Toyota Motor          Akio Toyoda
# ..                              ...                  ...
# 495  Teva Pharmaceutical Industries    Yitzhak Peterburg
# 496        New China Life Insurance             Wan Feng
# 497       Wm. Morrison Supermarkets       David T. Potts
# 498                             TUI    Friedrich Joussen
# 499                      AutoNation   Michael J. Jackson
#
#                             industry  rank
# 0              General Merchandisers     1
# 1                          Utilities     2
# 2                 Petroleum Refining     3
# 3                 Petroleum Refining     4
# 4           Motor Vehicles and Parts     5
# ...

# %%
for i in f500[["company","ceo","industry","rank"]]:
    print(i)
# Out:
# company
# ceo
# industry
# rank

# %%
f500[["company","ceo","industry","rank"]].tail()
# Out:
#                             company                 ceo  \
# 495  Teva Pharmaceutical Industries   Yitzhak Peterburg
# 496        New China Life Insurance            Wan Feng
# 497       Wm. Morrison Supermarkets      David T. Potts
# 498                             TUI   Friedrich Joussen
# 499                      AutoNation  Michael J. Jackson
#
#                             industry  rank
# 495                  Pharmaceuticals   496
# 496  Insurance: Life, Health (stock)   497
# 497             Food and Drug Stores   498
# 498                  Travel Services   499
# 499              Specialty Retailers   500

# %% [markdown]
# 1. iloc: will use when we have integer indexing
# 2. loc: will use when we have label indexing

# %%
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
f500.iloc[0]
# Out:
# company                                    Walmart
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: 0, dtype: object

# %%
f500.iloc[0,-4]
# Out:
# 'http://www.walmart.com'

# %%
f500.iloc[0,-1]
# Out:
# 77798

# %%
f500.iloc[5:10]
# Out:
#               company  rank  revenues  revenue_change  profits  assets  \
# 5          Volkswagen     6    240264             1.5   5937.3  432116
# 6   Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7  Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8               Apple     9    215639            -7.7  45687.0  321686
# 9         Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                ceo                                  industry  \
# 5            NaN    Matthias Muller                  Motor Vehicles and Parts
# 6          135.9    Ben van Beurden                        Petroleum Refining
# 7            NaN  Warren E. Buffett  Insurance: Property and Casualty (Stock)
# 8          -14.4    Timothy D. Cook               Computers, Office Equipment
# 9          -51.5    Darren W. Woods                        Petroleum Refining
#
# ...

# %%
f500.iloc[5:10,4]
# Out:
# 5     5937.3
# 6     4575.0
# 7    24074.0
# 8    45687.0
# 9     7840.0
# Name: profits, dtype: float64

# %%
f500.iloc[5:10,:4]
# Out:
#               company  rank  revenues  revenue_change
# 5          Volkswagen     6    240264             1.5
# 6   Royal Dutch Shell     7    240033           -11.8
# 7  Berkshire Hathaway     8    223604             6.1
# 8               Apple     9    215639            -7.7
# 9         Exxon Mobil    10    205004           -16.7

# %%
f500.iloc[5:10,4:]
# Out:
#    profits  assets  profit_change                ceo  \
# 5   5937.3  432116            NaN    Matthias Muller
# 6   4575.0  411275          135.9    Ben van Beurden
# 7  24074.0  620854            NaN  Warren E. Buffett
# 8  45687.0  321686          -14.4    Timothy D. Cook
# 9   7840.0  330314          -51.5    Darren W. Woods
#
#                                    industry                  sector  \
# 5                  Motor Vehicles and Parts  Motor Vehicles & Parts
# 6                        Petroleum Refining                  Energy
# 7  Insurance: Property and Casualty (Stock)              Financials
# 8               Computers, Office Equipment              Technology
# 9                        Petroleum Refining                  Energy
#
#    previous_rank      country             hq_location  \
# 5              7      Germany      Wolfsburg, Germany
# 6              5  Netherlands  The Hague, Netherlands
# 7             11          USA               Omaha, NE
# ...

# %%
f500.iloc[5]
# Out:
# company                                    Volkswagen
# rank                                                6
# revenues                                       240264
# revenue_change                                    1.5
# profits                                        5937.3
# assets                                         432116
# profit_change                                     NaN
# ceo                                   Matthias Muller
# industry                     Motor Vehicles and Parts
# sector                         Motor Vehicles & Parts
# previous_rank                                       7
# country                                       Germany
# hq_location                        Wolfsburg, Germany
# website                     http://www.volkswagen.com
# years_on_global_500_list                           23
# employees                                      626715
# total_stockholder_equity                        97753
# Name: 5, dtype: object

# %%
f500.iloc[5,8]
# Out:
# 'Motor Vehicles and Parts'

# %%
f500.iloc[[5,8],:3]
# Out:
#       company  rank  revenues
# 5  Volkswagen     6    240264
# 8       Apple     9    215639

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.iloc[2:5,[0,7]]
# Out:
#                     company            ceo
# 2             Sinopec Group      Wang Yupu
# 3  China National Petroleum  Zhang Jianhua
# 4              Toyota Motor    Akio Toyoda

# %%
f500.loc[2:4,["company","ceo"]]
# Out:
#                     company            ceo
# 2             Sinopec Group      Wang Yupu
# 3  China National Petroleum  Zhang Jianhua
# 4              Toyota Motor    Akio Toyoda

# %% [raw]
# f500.loc[2:4,"company":"ceo"]

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500 = f500.drop(2)
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
# 5            NaN      Matthias Muller  Motor Vehicles and Parts
#
#                    sector  previous_rank  country         hq_location  \
# ...

# %%
f500.drop(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 f500.drop(2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
f500.head()

# %%
f500.drop([1,3], inplace = True) # f500 = f500.drop([1,3])

# %%
f500.head()
# Out:
#               company  rank  revenues  revenue_change  profits  assets  \
# 0             Walmart     1    485873             0.8  13643.0  198825
# 4        Toyota Motor     5    254694             7.7  16899.3  437575
# 5          Volkswagen     6    240264             1.5   5937.3  432116
# 6   Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7  Berkshire Hathaway     8    223604             6.1  24074.0  620854
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 4          -12.3          Akio Toyoda
# 5            NaN      Matthias Muller
# 6          135.9      Ben van Beurden
# 7            NaN    Warren E. Buffett
#
#                                    industry                  sector  \
# 0                     General Merchandisers               Retailing
# 4                  Motor Vehicles and Parts  Motor Vehicles & Parts
# 5                  Motor Vehicles and Parts  Motor Vehicles & Parts
# ...

# %%
f500.drop("rank", axis = 1, inplace = True)   # axis 1 col axis 0 row
f500.head()
# Out:
#               company  revenues  revenue_change  profits  assets  \
# 0             Walmart    485873             0.8  13643.0  198825
# 4        Toyota Motor    254694             7.7  16899.3  437575
# 5          Volkswagen    240264             1.5   5937.3  432116
# 6   Royal Dutch Shell    240033           -11.8   4575.0  411275
# 7  Berkshire Hathaway    223604             6.1  24074.0  620854
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 4          -12.3          Akio Toyoda
# 5            NaN      Matthias Muller
# 6          135.9      Ben van Beurden
# 7            NaN    Warren E. Buffett
#
#                                    industry                  sector  \
# 0                     General Merchandisers               Retailing
# 4                  Motor Vehicles and Parts  Motor Vehicles & Parts
# 5                  Motor Vehicles and Parts  Motor Vehicles & Parts
# ...

# %%
pd.read_csv("f500.csv", header = None)
# Out:
#                                  0     1         2               3        4   \
# 0                           company  rank  revenues  revenue_change  profits
# 1                           Walmart     1    485873             0.8  13643.0
# 2                        State Grid     2    315199            -4.4   9571.3
# 3                     Sinopec Group     3    267518            -9.1   1257.9
# 4          China National Petroleum     4    262573           -12.3   1867.5
# ..                              ...   ...       ...             ...      ...
# 496  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 497        New China Life Insurance   497     21796           -13.3    743.9
# 498       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 499                             TUI   499     21655            -5.5   1151.7
# 500                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
pd.read_csv("f500.csv", header = 2)
# Out:
#                          State Grid    2  315199  -4.4   9571.3  489838  \
# 0                     Sinopec Group    3  267518  -9.1   1257.9  310726
# 1          China National Petroleum    4  262573 -12.3   1867.5  585619
# 2                      Toyota Motor    5  254694   7.7  16899.3  437575
# 3                        Volkswagen    6  240264   1.5   5937.3  432116
# 4                 Royal Dutch Shell    7  240033 -11.8   4575.0  411275
# ..                              ...  ...     ...   ...      ...     ...
# 493  Teva Pharmaceutical Industries  496   21903  11.5    329.0   92890
# 494        New China Life Insurance  497   21796 -13.3    743.9  100609
# 495       Wm. Morrison Supermarkets  498   21741 -11.3    406.4   11630
# 496                             TUI  499   21655  -5.5   1151.7   16247
# 497                      AutoNation  500   21609   3.6    430.5   10060
#
#       -6.2             Kou Wei                        Utilities  \
# ...

# %%
f500 = pd.read_csv("f500.csv")
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500 = pd.read_csv("f500.csv" , index_col = 0)
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# ...

# %%
f500.index.name = None

# %%
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# ...

# %%
f500.loc["Walmart"]
# Out:
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: Walmart, dtype: object

# %%
f500.iloc[0]
# Out:
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: Walmart, dtype: object

# %%
f500.loc["Walmart":"Toyota Motor"]
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# ...

# %%
f500.iloc[0:5]
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# ...

# %%
f500.loc[0:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 f500.loc[0:4]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1373, in _LocIndexer._getitem_axis(self, key, axis)
#    1371 if isinstance(key, slice):
#    1372     self._validate_key(key, axis)
# -> 1373     return self._get_slice_axis(key, axis=axis)
#    1374 elif com.is_bool_indexer(key):
#    1375     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1405, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1402     return obj.copy(deep=False)
# ...

# %%
print("-"*100)

# %%
# del f500["rank"]

# %%
f500

# %%
f500.dtypes

# %%
f500.iloc[4,1]

# %%
f500.iloc[4,1] += 100
f500.iloc[4,1]

# %%
f500.loc["Toyota Motor","revenues"]

# %%
f500.loc["Toyota Motor","revenues"] += 100
f500.loc["Toyota Motor","revenues"]

# %%
f500.head()

# %%
f500['country']

# %%
country_frq = {}                 # china = 1+1+1+1

for key in f500["country"]:
    if key not in country_frq:
        country_frq[key] = 1
    else:
        country_frq[key] += 1

# %%
country_frq
# Out:
# {'USA': 132,
#  'China': 109,
#  'Japan': 51,
#  'Germany': 29,
#  'Netherlands': 14,
#  'Britain': 24,
#  'South Korea': 15,
#  'Switzerland': 14,
#  'France': 29,
#  'Taiwan': 6,
#  'Singapore': 3,
#  'Italy': 7,
#  'Russia': 4,
#  'Spain': 9,
#  'Brazil': 7,
#  'Mexico': 2,
#  'Luxembourg': 1,
#  'India': 7,
#  'Malaysia': 1,
#  'Thailand': 1,
#  'Australia': 7,
#  'Belgium': 1,
#  'Norway': 1,
#  'Canada': 11,
#  'Ireland': 4,
#  'Indonesia': 1,
#  'Denmark': 1,
#  'Saudi Arabia': 1,
#  'Sweden': 3,
#  'Finland': 1,
#  'Venezuela': 1,
#  'Turkey': 1,
#  'U.A.E': 1,
#  'Israel': 1}

# %%
type(f500)
# Out:
# pandas.core.frame.DataFrame

# %%
type(f500["country"])
# Out:
# pandas.core.series.Series

# %%
frq = f500["country"].value_counts()
frq
# Out:
# country
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Luxembourg        1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: count, dtype: int64

# %%
type(frq)
# Out:
# pandas.core.series.Series

# %%
frq["Denmark"]
# Out:
# 1

# %% [markdown]
# # Logical Operators in Pandas:
#     * & (and)
#     * | (or)
#     * ~ (not)

# %%
f500["country"].unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %%
len(f500["country"].unique())
# Out:
# 34

# %%
f500['country'] == "India"
# Out:
# Walmart                           False
# State Grid                        False
# Sinopec Group                     False
# China National Petroleum          False
# Toyota Motor                      False
#                                   ...
# Teva Pharmaceutical Industries    False
# New China Life Insurance          False
# Wm. Morrison Supermarkets         False
# TUI                               False
# AutoNation                        False
# Name: country, Length: 500, dtype: bool

# %%
f500[f500["country"] == "India"]
# Out:
#                      rank  revenues  revenue_change  profits  assets  \
# Indian Oil            168     53562            -2.1   2960.0   42132
# Reliance Industries   203     46931             8.0   4458.9  108856
# State Bank of India   217     44533             6.8     36.0  530590
# Tata Motors           247     40329            -4.2   1111.6   42162
# Rajesh Exports        295     36114            43.1    185.8    3717
# Bharat Petroleum      360     30316             4.2   1300.5   16801
# Hindustan Petroleum   384     28166            -2.3   1228.1   12370
#
#                      profit_change                     ceo  \
# Indian Oil                    72.7            Sanjiv Singh
# Reliance Industries            5.6        Mukesh D. Ambani
# State Bank of India          -98.1  Arundhati Bhattacharya
# Tata Motors                  -34.0        Guenter Butschek
# Rajesh Exports                13.8         Rajesh J. Mehta
# ...

# %%
f500[f500["country"] == "Brazil"]
# Out:
#                        rank  revenues  revenue_change  profits  assets  \
# Petrobras                75     81405           -16.3  -4838.0  246983
# Itau Unibanco Holding   113     66876            21.4   6666.4  415972
# Banco do Brasil         151     58093           -13.4   2013.8  426416
# Banco Bradesco          154     57443            31.3   5127.9  366418
# JBS                     191     48825            -0.1    107.7   31605
# Vale                    370     29363            14.7   3982.0   99014
# Ultrapar Holdings       487     22167            -2.3    447.5    7426
#
#                        profit_change                        ceo  \
# Petrobras                        NaN       Pedro Pullen Parente
# Itau Unibanco Holding          -13.7    Candido Botelho Bracher
# Banco do Brasil                -52.3   Paulo Rogerio Caffarelli
# Banco Bradesco                  -5.7  Luiz Carlos Trabuco Cappi
# JBS                            -92.3    Wesley Mendonca Batista
# ...

# %%
india_bool = f500["country"] == "India"
india_bool
# Out:
# Walmart                           False
# State Grid                        False
# Sinopec Group                     False
# China National Petroleum          False
# Toyota Motor                      False
#                                   ...
# Teva Pharmaceutical Industries    False
# New China Life Insurance          False
# Wm. Morrison Supermarkets         False
# TUI                               False
# AutoNation                        False
# Name: country, Length: 500, dtype: bool

# %%
pd.options.display.max_rows = None

# %%
india_bool
# Out:
# Walmart                                         False
# State Grid                                      False
# Sinopec Group                                   False
# China National Petroleum                        False
# Toyota Motor                                    False
# Volkswagen                                      False
# Royal Dutch Shell                               False
# Berkshire Hathaway                              False
# Apple                                           False
# Exxon Mobil                                     False
# McKesson                                        False
# BP                                              False
# UnitedHealth Group                              False
# CVS Health                                      False
# Samsung Electronics                             False
# Glencore                                        False
# Daimler                                         False
# ...

# %%
f500.loc[india_bool]
# Out:
#                      rank  revenues  revenue_change  profits  assets  \
# Indian Oil            168     53562            -2.1   2960.0   42132
# Reliance Industries   203     46931             8.0   4458.9  108856
# State Bank of India   217     44533             6.8     36.0  530590
# Tata Motors           247     40329            -4.2   1111.6   42162
# Rajesh Exports        295     36114            43.1    185.8    3717
# Bharat Petroleum      360     30316             4.2   1300.5   16801
# Hindustan Petroleum   384     28166            -2.3   1228.1   12370
#
#                      profit_change                     ceo  \
# Indian Oil                    72.7            Sanjiv Singh
# Reliance Industries            5.6        Mukesh D. Ambani
# State Bank of India          -98.1  Arundhati Bhattacharya
# Tata Motors                  -34.0        Guenter Butschek
# Rajesh Exports                13.8         Rajesh J. Mehta
# ...

# %%
f500.loc[india_bool, ["rank","ceo"]]
# Out:
#                      rank                     ceo
# Indian Oil            168            Sanjiv Singh
# Reliance Industries   203        Mukesh D. Ambani
# State Bank of India   217  Arundhati Bhattacharya
# Tata Motors           247        Guenter Butschek
# Rajesh Exports        295         Rajesh J. Mehta
# Bharat Petroleum      360             D. Rajkumar
# Hindustan Petroleum   384     Mukesh Kumar Surana

# %%
f500["sector"].unique()
# Out:
# array(['Retailing', 'Energy', 'Motor Vehicles & Parts', 'Financials',
#        'Technology', 'Wholesalers', 'Health Care', 'Telecommunications',
#        'Engineering & Construction', 'Industrials', 'Food & Drug Stores',
#        'Aerospace & Defense', 'Food, Beverages & Tobacco',
#        'Household Products', 'Transportation', 'Materials', 'Chemicals',
#        'Media', 'Apparel', 'Hotels, Restaurants & Leisure',
#        'Business Services'], dtype=object)

# %%
f500['sector'] == "Technology"
# Out:
# Walmart                                         False
# State Grid                                      False
# Sinopec Group                                   False
# China National Petroleum                        False
# Toyota Motor                                    False
# Volkswagen                                      False
# Royal Dutch Shell                               False
# Berkshire Hathaway                              False
# Apple                                            True
# Exxon Mobil                                     False
# McKesson                                        False
# BP                                              False
# UnitedHealth Group                              False
# CVS Health                                      False
# Samsung Electronics                              True
# Glencore                                        False
# Daimler                                         False
# ...

# %%
f500["country"] == "USA"
# Out:
# Walmart                                          True
# State Grid                                      False
# Sinopec Group                                   False
# China National Petroleum                        False
# Toyota Motor                                    False
# Volkswagen                                      False
# Royal Dutch Shell                               False
# Berkshire Hathaway                               True
# Apple                                            True
# Exxon Mobil                                      True
# McKesson                                         True
# BP                                              False
# UnitedHealth Group                               True
# CVS Health                                       True
# Samsung Electronics                             False
# Glencore                                        False
# Daimler                                         False
# ...

# %%
f500.loc[(f500["sector"] == "Technology") & (f500["country"] == "USA")]
# Out:
#                             rank  revenues  revenue_change  profits  assets  \
# Apple                          9    215639            -7.7  45687.0  321686
# Amazon.com                    26    135987            27.1   2371.0   83402
# Alphabet                      65     90272            20.4  19478.0  167497
# Microsoft                     69     85320            -8.8  16798.0  193694
# IBM                           81     79919            -3.1  11872.0  117470
# Dell Technologies            124     64806            18.1  -1672.0  118206
# Intel                        144     59387             7.3  10316.0  113327
# Hewlett Packard Enterprise   181     50123             NaN   3161.0   79679
# Cisco Systems                187     49247             0.2  10739.0  121652
# HP                           194     48238           -53.3   2496.0   29010
# Honeywell International      260     39302             1.9   4809.0   54146
# ...

# %%
f500.loc[(f500["sector"] == "Technology") & ~(f500["country"] == "USA")]
# Out:
#                                     rank  revenues  revenue_change  profits  \
# Samsung Electronics                   15    173957            -2.0  19316.5
# Hon Hai Precision Industry            27    135129            -4.3   4608.8
# Hitachi                               71     84558             1.2   2134.3
# Huawei Investment & Holding           83     78511            24.9   5579.4
# Sony                                 105     70170             3.9    676.4
# Panasonic                            110     67775             6.7   1378.4
# Amer International Group             183     49677             3.9   1199.9
# LG Electronics                       201     47712            -4.6     66.2
# Lenovo Group                         226     43035            -4.2    535.1
# Fujitsu                              237     41620             5.4    816.7
# JD.com                               261     39155            35.7   -573.0
# ...

# %%
f500 = pd.read_csv("f500.csv")
f500
# Out:
#                                           company  rank  revenues  \
# 0                                         Walmart     1    485873
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 4                                    Toyota Motor     5    254694
# 5                                      Volkswagen     6    240264
# 6                               Royal Dutch Shell     7    240033
# 7                              Berkshire Hathaway     8    223604
# 8                                           Apple     9    215639
# 9                                     Exxon Mobil    10    205004
# 10                                       McKesson    11    198533
# 11                                             BP    12    186606
# 12                             UnitedHealth Group    13    184840
# ...

# %%
f500[f500["country"] == "Germany"]
# Out:
#                      company  rank  revenues  revenue_change  profits  \
# 5                 Volkswagen     6    240264             1.5   5937.3
# 16                   Daimler    17    169483             2.2   9428.4
# 33                   Allianz    34    122196            -0.6   7611.5
# 51                 BMW Group    52    104130             1.8   7589.4
# 65                   Siemens    66     88419             0.9   6050.5
# 75              Robert Bosch    76     80869             3.3   2155.3
# 76          Deutsche Telekom    77     80832             5.3   2958.1
# 90                    Uniper    91     74407             NaN  -3557.5
# 108          Munich Re Group   109     68700            -1.1   2853.1
# 116  Deutsche Post DHL Group   117     65787            -3.8   2918.3
# 122                    Metro   123     64853            -9.0    665.0
# 125                     BASF   126     63641           -18.6   4485.3
# ...

# %%
germany_df = f500[f500["country"] == "Germany"]
germany_df.head()
# Out:
#        company  rank  revenues  revenue_change  profits  assets  \
# 5   Volkswagen     6    240264             1.5   5937.3  432116
# 16     Daimler    17    169483             2.2   9428.4  256262
# 33     Allianz    34    122196            -0.6   7611.5  932091
# 51   BMW Group    52    104130             1.8   7589.4  198835
# 65     Siemens    66     88419             0.9   6050.5  141271
#
#     profit_change              ceo                                  industry  \
# 5             NaN  Matthias Muller                  Motor Vehicles and Parts
# 16            0.9   Dieter Zetsche                  Motor Vehicles and Parts
# 33            3.7      Oliver Bate  Insurance: Property and Casualty (Stock)
# 51            7.4    Harald Kruger                  Motor Vehicles and Parts
# 65          -27.4     Josef Kaeser                      Industrial Machinery
#
#                     sector  previous_rank  country         hq_location  \
# ...

# %%
germany_df.sort_values("employees")
# Out:
#                      company  rank  revenues  revenue_change  profits  \
# 456          Heraeus Holding   457     23793            65.9      NaN
# 90                    Uniper    91     74407             NaN  -3557.5
# 301                   Talanx   302     35101            -0.8   1003.0
# 402     Phoenix Pharmahandel   403     26976             5.2    135.4
# 326                  DZ Bank   327     32636             4.6   1623.4
# 230                     E.ON   231     42213           -67.3  -9344.4
# 108          Munich Re Group   109     68700            -1.1   2853.1
# 194                      RWE   195     48204            -6.6  -6249.1
# 498                      TUI   499     21655            -5.5   1151.7
# 442                      SAP   443     24397             5.8   4031.9
# 188            Deutsche Bank   189     48876            -6.8  -1550.4
# 302          Lufthansa Group   303     35011            -1.5   1964.0
# ...

# %%
germany_df_sort_employees = \
germany_df.sort_values("employees", ascending=False)

# %%
germany_df_sort_employees
# Out:
#                      company  rank  revenues  revenue_change  profits  \
# 5                 Volkswagen     6    240264             1.5   5937.3
# 116  Deutsche Post DHL Group   117     65787            -3.8   2918.3
# 75              Robert Bosch    76     80869             3.3   2155.3
# 308           Edeka Zentrale   309     34193             6.8    356.0
# 65                   Siemens    66     88419             0.9   6050.5
# 211            Deutsche Bahn   212     44850             0.1    768.6
# 16                   Daimler    17    169483             2.2   9428.4
# 334                Fresenius   335     32161             4.9   1761.6
# 76          Deutsche Telekom    77     80832             5.3   2958.1
# 212              Continental   213     44842             3.0   3099.1
# 122                    Metro   123     64853            -9.0    665.0
# 223             ThyssenKrupp   224     43589           -11.0    328.6
# ...

# %%
germany_df_sort_employees.iloc[0,0]
# Out:
# 'Volkswagen'

# %%
countries = f500["country"].unique()
countries
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %%
top_employer_by_country = {}

for c in countries:
    df = f500[f500["country"] == c]
    sort_employees = df.sort_values("employees", ascending=False)
    top_employer = sort_employees.iloc[0,0]
    top_employer_by_country[c] = top_employer

# %%
top_employer_by_country
# Out:
# {'USA': 'Walmart',
#  'China': 'China National Petroleum',
#  'Japan': 'Toyota Motor',
#  'Germany': 'Volkswagen',
#  'Netherlands': 'EXOR Group',
#  'Britain': 'Compass Group',
#  'South Korea': 'Samsung Electronics',
#  'Switzerland': 'Nestle',
#  'France': 'Sodexo',
#  'Taiwan': 'Hon Hai Precision Industry',
#  'Singapore': 'Flex',
#  'Italy': 'Poste Italiane',
#  'Russia': 'Gazprom',
#  'Spain': 'Banco Santander',
#  'Brazil': 'JBS',
#  'Mexico': 'America Movil',
#  'Luxembourg': 'ArcelorMittal',
#  'India': 'State Bank of India',
#  'Malaysia': 'Petronas',
#  'Thailand': 'PTT',
#  'Australia': 'Wesfarmers',
#  'Belgium': 'Anheuser-Busch InBev',
#  'Norway': 'Statoil',
#  'Canada': 'George Weston',
#  'Ireland': 'Accenture',
#  'Indonesia': 'Pertamina',
#  'Denmark': 'Maersk Group',
#  'Saudi Arabia': 'SABIC',
#  'Sweden': 'H & M Hennes & Mauritz',
#  'Finland': 'Nokia',
#  'Venezuela': 'Mercantil Servicios Financieros',
#  'Turkey': 'Koc Holding',
#  'U.A.E': 'Emirates Group',
# ...

# %%
top_employer_by_country = pd.Series()

for c in countries:
    df = f500[f500["country"] == c]
    sort_employees = df.sort_values("employees", ascending=False)
    top_employer = sort_employees.iloc[0,0]
    top_employer_by_country[c] = top_employer

# %%
top_employer_by_country
# Out:
# USA                                     Walmart
# China                  China National Petroleum
# Japan                              Toyota Motor
# Germany                              Volkswagen
# Netherlands                          EXOR Group
# Britain                           Compass Group
# South Korea                 Samsung Electronics
# Switzerland                              Nestle
# France                                   Sodexo
# Taiwan               Hon Hai Precision Industry
# Singapore                                  Flex
# Italy                            Poste Italiane
# Russia                                  Gazprom
# Spain                           Banco Santander
# Brazil                                      JBS
# Mexico                            America Movil
# Luxembourg                        ArcelorMittal
# India                       State Bank of India
# Malaysia                               Petronas
# Thailand                                    PTT
# ...

# %%
type(top_employer_by_country)
# Out:
# pandas.core.series.Series

# %%
top_employer_by_country.to_dict()
# Out:
# {'USA': 'Walmart',
#  'China': 'China National Petroleum',
#  'Japan': 'Toyota Motor',
#  'Germany': 'Volkswagen',
#  'Netherlands': 'EXOR Group',
#  'Britain': 'Compass Group',
#  'South Korea': 'Samsung Electronics',
#  'Switzerland': 'Nestle',
#  'France': 'Sodexo',
#  'Taiwan': 'Hon Hai Precision Industry',
#  'Singapore': 'Flex',
#  'Italy': 'Poste Italiane',
#  'Russia': 'Gazprom',
#  'Spain': 'Banco Santander',
#  'Brazil': 'JBS',
#  'Mexico': 'America Movil',
#  'Luxembourg': 'ArcelorMittal',
#  'India': 'State Bank of India',
#  'Malaysia': 'Petronas',
#  'Thailand': 'PTT',
#  'Australia': 'Wesfarmers',
#  'Belgium': 'Anheuser-Busch InBev',
#  'Norway': 'Statoil',
#  'Canada': 'George Weston',
#  'Ireland': 'Accenture',
#  'Indonesia': 'Pertamina',
#  'Denmark': 'Maersk Group',
#  'Saudi Arabia': 'SABIC',
#  'Sweden': 'H & M Hennes & Mauritz',
#  'Finland': 'Nokia',
#  'Venezuela': 'Mercantil Servicios Financieros',
#  'Turkey': 'Koc Holding',
#  'U.A.E': 'Emirates Group',
# ...

# %%
f = f500

# %%
f['company'].unique
# Out:
# <bound method Series.unique of 0                                           Walmart
# 1                                        State Grid
# 2                                     Sinopec Group
# 3                          China National Petroleum
# 4                                      Toyota Motor
# 5                                        Volkswagen
# 6                                 Royal Dutch Shell
# 7                                Berkshire Hathaway
# 8                                             Apple
# 9                                       Exxon Mobil
# 10                                         McKesson
# 11                                               BP
# 12                               UnitedHealth Group
# 13                                       CVS Health
# 14                              Samsung Electronics
# 15                                         Glencore
# 16                                          Daimler
# ...

# %%
d = f['company'] == 'W

# %%
ff = f[d]

# %%
plt.bar(f['company'],f['rank'])
plt.xticks(rotation = 90)
plt.show()
